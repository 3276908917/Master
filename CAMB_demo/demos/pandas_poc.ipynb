# %%
import import_model as im
import re
import numpy as np

# %%
Al = im.import_model("cosmology_Aletheia.dat")

# %%
Al.loc[0]["z(4)"]
# Out:
# 2.0

# %%
redshift_column = re.compile("z.+")
np.where(redshift_column.match(Al.columns))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22448\1824467194.py in <module>
#       1 redshift_column = re.compile("z.+")
# ----> 2 np.where(redshift_column.match(Al.columns))
#
# TypeError: expected string or bytes-like object

# %%
for column in Al.columns:
    print(redshift_column.match(column))
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <re.Match object; span=(0, 4), match='z(4)'>
# <re.Match object; span=(0, 4), match='z(3)'>
# <re.Match object; span=(0, 4), match='z(2)'>
# <re.Match object; span=(0, 4), match='z(1)'>
# <re.Match object; span=(0, 4), match='z(0)'>
# None
# None

# %%
Al
# Out:
#          Name     ombh2     omch2   n_s           A_s       OmB       OmC  \
# 0  Columbus_0  0.022445  0.120567  0.96  2.127238e-09  0.050000  0.268584
# 1  Columbus_1  0.022445  0.120567  0.96  1.785684e-09  0.074198  0.398570
# 2  Columbus_2  0.022445  0.120567  0.96  2.484859e-09  0.035964  0.193186
# 3  Columbus_3  0.022445  0.120567  0.96  2.320710e-09  0.050000  0.268584
# 4  Columbus_4  0.022445  0.120567  0.96  1.995537e-09  0.050000  0.268584
# 5  Columbus_5  0.022445  0.120567  0.96  2.070770e-09  0.050000  0.268584
# 6  Columbus_6  0.022445  0.120567  0.96  2.201964e-09  0.050000  0.268584
# 7  Columbus_7  0.022445  0.120567  0.96  1.929616e-09  0.050000  0.268584
# 8  Columbus_8  0.022445  0.120567  0.96  2.292917e-09  0.050000  0.268584
#
#         OmM   OmK       OmL  ...    w0     wa EOmDE      z(4)      z(3)  \
# 0  0.318584  0.00  0.681416  ... -1.00   0.00     -  2.000000  1.000000
# 1  0.472768  0.00  0.527232  ... -1.00   0.00     -  1.760980  0.859383
# ...

# %%
Al.loc[0]["w0"]
# Out:
# -1.0
